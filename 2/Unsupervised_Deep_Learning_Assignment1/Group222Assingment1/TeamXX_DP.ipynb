# %% [markdown]
# # TeamXX_DP
# Replace G with your group number.

# %%
from datetime import datetime
print('Timestamp:', datetime.now())
G=1  # TODO: replace with group number
print('DP Assignment Template')
# Out:
# Timestamp: 2026-06-02 21:01:13.451913
# DP Assignment Template
