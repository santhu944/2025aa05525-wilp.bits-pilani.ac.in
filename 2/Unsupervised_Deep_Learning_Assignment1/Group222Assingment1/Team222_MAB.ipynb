# %% [markdown]
# # Team222_MAB Assignment
# Group Number = 222

# %%
# ==================================================
# SECTION 1 : IMPORTS
# ==================================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from collections import defaultdict
from datetime import datetime

# %%
# ==================================================
# SECTION 2 : GROUP CONFIGURATION
# ==================================================

# %%
GROUP_ID = 222

print("Timestamp :", datetime.now())

GRID_SIZE = 5
MAX_BATTERY = 10
WIND_PROB = 0.20
MAX_STEPS = 50

print("Group =", GROUP_ID)
print("Grid =", GRID_SIZE)
print("Battery =", MAX_BATTERY)
# Out:
# Timestamp : 2026-06-02 22:44:33.784701
# Group = 222
# Grid = 5
# Battery = 10

# %%
# ==================================================
# SECTION 3 : ENVIRONMENT DESIGN
# ==================================================

# %%
GRID = [
['S','F','F','D','F'],
['F','X','F','F','F'],
['R','F','W','D','F'],
['F','F','F','X','F'],
['C','F','R','D','F']
]

# %%
LEGEND = {
    'S': 'Start Position',
    'F': 'Free Cell',
    'R': 'Rescue Target',
    'D': 'Danger Zone',
    'C': 'Charging Station',
    'W': 'Wind Zone',
    'X': 'Blocked Cell'
}

print(LEGEND)
# Out:
# {'S': 'Start Position', 'F': 'Free Cell', 'R': 'Rescue Target', 'D': 'Danger Zone', 'C': 'Charging Station', 'W': 'Wind Zone', 'X': 'Blocked Cell'}

# %%
GRID = [
    ['S','F','F','D','F'],
    ['F','X','F','F','F'],
    ['R','F','W','D','F'],
    ['F','F','F','X','F'],
    ['C','F','R','D','F']
]

# %%
for row in GRID:
    print(row)
# Out:
# ['S', 'F', 'F', 'D', 'F']
# ['F', 'X', 'F', 'F', 'F']
# ['R', 'F', 'W', 'D', 'F']
# ['F', 'F', 'F', 'X', 'F']
# ['C', 'F', 'R', 'D', 'F']
