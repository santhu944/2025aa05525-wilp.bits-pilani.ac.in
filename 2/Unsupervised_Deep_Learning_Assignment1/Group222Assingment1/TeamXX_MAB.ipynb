# %% [markdown]
# # TeamXX_MAB
# Replace G with your group number.

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from datetime import datetime
print('Timestamp:', datetime.now())
G = 1  # TODO: replace with your group number
random.seed(G)
np.random.seed(G)
K = (G % 3) + 5
print('K=', K)
hidden_probs=[0.4 + ((G+i)%6)*0.07 for i in range(K)]
print(hidden_probs)
# Out:
# Timestamp: 2026-06-02 21:01:08.094141
# K= 6
# [0.47000000000000003, 0.54, 0.6100000000000001, 0.68, 0.75, 0.4]

# %%
patients=[]
for patient_id in range(1000):
    patients.append({'patient_id':patient_id,'severity_score':(patient_id%5)+1})
df=pd.DataFrame(patients)
df.head(10)
# Out:
#    patient_id  severity_score
# 0           0               1
# 1           1               2
# 2           2               3
# 3           3               4
# 4           4               5
# 5           5               1
# 6           6               2
# 7           7               3
# 8           8               4
# 9           9               5
