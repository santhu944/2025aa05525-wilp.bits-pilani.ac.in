# %% [markdown]
# # Team222_MAB Assignment
# Group Number = 222

# %%
import numpy as np, pandas as pd, random, matplotlib.pyplot as plt
from datetime import datetime
G=222
random.seed(G)
np.random.seed(G)
print('Timestamp:', datetime.now())
K=5
print('Medicines:',K)
hidden_probs=[0.4, 0.47, 0.54, 0.61, 0.68]
print(hidden_probs)

# %%
df=pd.DataFrame({'patient_id':range(1000)})
df['severity_score']=(df['patient_id']%5)+1
df.head(10)

# %%
def reward(outcome,severity):
    return outcome*(1-severity/10)
# Implement Greedy, Epsilon-Greedy and UCB1 here
