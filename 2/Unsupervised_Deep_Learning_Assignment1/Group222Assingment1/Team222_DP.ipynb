# %% [markdown]
# # Team222_DP Assignment
# Group Number = 222

# %%
from datetime import datetime
print('Timestamp:', datetime.now())
G=222
GRID_SIZE=5
MAX_BATTERY=10
WIND_PROB=0.2
print(GRID_SIZE,MAX_BATTERY,WIND_PROB)
# Out:
# Timestamp: 2026-06-02 21:03:34.417758
# 5 10 0.2

# %%
# Create DroneRescueEnv, Value Iteration, Policy Visualization
