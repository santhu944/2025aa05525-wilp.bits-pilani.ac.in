# %%
# !python train_models.py
# Out:
# Dataset Loaded Successfully!
# Shape: (30000, 23)
#    LIMIT_BAL  AGE  INCOME  ...  PAY_AMT5  PAY_AMT6  risk_level
# 0     171958   52  131631  ...    186556     53488           2
# 1     721155   27  132984  ...    134421    150891           1
# 2     181932   34   69428  ...     96130     56704           2
# 3     415838   68   69877  ...    189949     35187           2
# 4     309178   59  174459  ...     54901    168045           2
#
# [5 rows x 23 columns]
#
# ========== Logistic Regression ==========
# Accuracy  : 0.6178
# AUC Score : 0.7359
# Precision : 0.6174
# Recall    : 0.6178
# F1 Score  : 0.6176
# MCC Score : 0.3309
#
# Confusion Matrix:
# [[ 412   70    0]
#  [  80 1564 1072]
#  [   0 1071 1731]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       482
#            1       0.58      0.58      0.58      2716
#            2       0.62      0.62      0.62      2802
#
# ...
